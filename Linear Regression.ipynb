# %% [markdown]
# # Linear Regression
#
# #### What is Linear Regression
#
# * A linear regression is to predict a value of dependent variable given the independent variable(s)
# * Example:
#     * y = Ax + B
#     * x is independent variable: for example weight
#     * y is dependent variable: for example height

# %% [markdown]
# ### Example of Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

# Generate a random values of x and y (y values depends on the x values)
n = 50
x = np.random.randn(n)
y = x * np.random.randn(n)

# plot these values
colors = np.random.rand(n)
## np.poly1d => turns the array into polyominal equation
## np.polyfit => minimizes the squared error to fit the line
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel('x axes')
plt.ylabel('y axes')
plt.show()

# %% [markdown]
# ### Goal of Linear Regression
#
# * Minimize the errors to fit the points
# * We can adjust two things in equation y = Ax + B
#     * Coefficient: A
#     * Bias/intercept: B
